# %%
a=[10,20,30]

# %%
a
# Out:
# [10, 20, 30]

# %%
import numpy as np
a = [[3,4,5,6,7,8,9],[4,5,6,7,8,9,6]]
print(np.ndim(a))
# Out:
# 2

# %%
import numpy as np
ar = np.array([3,4,5,6,7,8,9])
ar + 5
# Out:
# array([ 8,  9, 10, 11, 12, 13, 14])
