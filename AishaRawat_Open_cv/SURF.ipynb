# %% [markdown]
# # SURF
#
# SURF is a feature descriptor algorithm . It is more dyanamic and robust than SIFT. It will run only on version 3 because it's patent rights are only associated with it .

# %% [markdown]
# #### change the version of opencv from 4 to 3 with two commands

# %%
pip install opencv-python==3.4.2.16
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
'--user'
# Out:
# '--user'

# %%
pip install opencv-contrib-python==3.4.2.16
# Out:
# ...
#   Using cached opencv_contrib_python-3.4.2.16-cp37-cp37m-win_amd64.whl (39.6 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import Libraries

# %%
import cv2

# %%
import  numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# # Read the Image

# %%
image= cv2.imread('rahul-gandhi_1526743864.jpeg')

# %%
plt.imshow(image)

# %%
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %% [markdown]
# # Instantiate surf object

# %%
surf  = cv2.xfeatures2d.SURF_create(400)

# %% [markdown]
# # Keypoints

# %%
keypoints,descriptors = surf.detectAndCompute(gray,None)

with_keypoints = cv2.drawKeypoints(gray,keypoints,outImage=None)

plt.imshow(with_keypoints)
