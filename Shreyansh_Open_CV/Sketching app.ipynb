# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def sketch(img):
    gray_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    blur_img = cv2.GaussianBlur(gray_img,(3,3),0)
    med_val = np.median(img)
    lower = int(max(0,0.7*med_val))
    upper = int(min(255,1.3*med_val))
    edges = cv2.Canny(blur_img,lower,upper-90)
    ret,m_ming = cv2.threshold(edges,50,255,cv2.THRESH_BINARY_INV)
    return m_ming

# %%
# Capturing video from webcam
vid_capt=cv2.VideoCapture(0)
# Capturing the video frame by frame
while True:
    ret,pic_capt=vid_capt.read()
    cv2.imshow('Your Sketch',sketch(pic_capt))
   # Key13 is ENTER_KEY
    if cv2.waitKey(1)==13:
        break

# releasing_webcam
vid_capt.release()
# destroying_window
cv2.destroyAllWindows()

# %%
akshita = cv2.imread('Akshita.png')
# final_akshita = sketch(akshita)
med_val = np.median(akshita)
lower = int(max(0,0.7*med_val))
upper = int(min(255,1.3*med_val))
blurred_img = cv2.blur(akshita,ksize=(5,5))
edges = cv2.Canny(image=blurred_img, threshold1=lower , threshold2=upper-120)
plt.imshow(edges,cmap='gray')
# cv2.imshow("Akshita",final_akshita)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
